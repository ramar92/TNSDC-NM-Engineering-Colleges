# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Unsupervised learning
#   1. Clustring
#   2. Associations
#
# #Types of Clustering
#   1. K-Mean - data divided based on K values
#   2. Hierarchical - Tree structed
#   3. DBSCAN - Based on data density
#   4. Mean-shift - Mode seeking
#
# #Association Rules:
#   1. Apriori  - Rule inductions
#   2. FP- Growth - alternative for Apriori
#   3. Eclat - exploiting the closed item
#   4. Efficient Tree-based  - large amount of data
