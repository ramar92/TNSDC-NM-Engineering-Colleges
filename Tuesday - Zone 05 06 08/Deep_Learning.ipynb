# %% [markdown]
# **Deep Learning**

# %%
AI - Mimic like Human
   - ML  - Statical Model
   - DL  - Nerual network <-- Biological NN
   - NLP -
   - CV -

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
   Human                  NN
1. Learn  <--------->    Learn
2. memory <--------->    Memory
3. compution <---------> compution

# %%
1. ANN (Artificial neural networks)

# %%
1. ML vs DL
2. DL Application
3. Types of NN
4. Perceptron / single neuron
5. Activation Function
6. ANN

# %% [markdown]
# **ML vs DL**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **DL Application**
# 1. Computer Vision
#     - Object detection and recognition
#     - Image classification
#     - Image segmentation
# 2. NLP
#     - Automatic Text Generator
#     - Language translation
#     - Sentiment analysis
#     - Speech recognition

# %% [markdown]
# **Types of NN**
#
# 1. Feedforward neural networks (FNNs)
# 2. Convolutional Neural Networks (CNNs)
# 3. Recurrent Neural Networks (RNNs)

# %% [markdown]
# **Perceptron**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Components**
#
# 1. Input features
# 2. Weight
# 3. Summation Function
# 4. Activation Function
# 5. Output
# 6. Bias

# %% [markdown]
# **Activation Function**
# 1. Sigmoid Function - 0 to  1 t = 0.5  *
# 2. ReLU - f(x) = m(0,x) *
# 3. Leakly ReLU -  f(x) = ax, x < 0 ,f(x) = x, x < others
# 4. tanh - -1 to 1 t = 0
# 5. Softmax - 3.. morethan *

# %% [markdown]
# **Deep Learning Algorithms :**
# 1. Convolutional Neural Networks (CNNs)
# 2. Long Short Term Memory Networks (LSTMs)
# 3. Recurrent Neural Networks (RNNs)
# 4. Generative Adversarial Networks (GANs)
# 5. Radial Basis Function Networks (RBFNs)
# 6. Multilayer Perceptrons (MLPs)
# 7. Self Organizing Maps (SOMs)
# 8. Deep Belief Networks (DBNs)
# 9. Restricted Boltzmann Machines( RBMs)
# 10. Autoencoders
