# %%
import pandas as pd
import numpy as np

datasets = pd.read_csv('/content/50_Startups.csv')

# %%
datasets.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
datasets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
datasets.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
le = LabelEncoder()

datasets['State'] = le.fit_transform(datasets['State'])

# %%
datasets.head()
# Out:
#    R&D Spend  Administration  Marketing Spend  State     Profit
# 0  165349.20       136897.80        471784.10      2  192261.83
# 1  162597.70       151377.59        443898.53      0  191792.06
# 2  153441.51       101145.55        407934.54      1  191050.39
# 3  144372.41       118671.85        383199.62      2  182901.99
# 4  142107.34        91391.77        366168.42      1  166187.94

# %%
#selected Input data
X = datasets.iloc[:, :-1]
#output
y = datasets.iloc[:, 4]

# %%
ohe = OneHotEncoder()

X = ohe.fit_transform(X).toarray()

# %%
X = X[:, 1:]

# %%
#split data
from sklearn.model_selection import train_test_split

X_Train, X_Test, Y_Train, Y_Test = train_test_split(X,y, test_size =0.2, random_state =0 )

# %%
# MLR model

from sklearn.linear_model import LinearRegression

#create the model
mlr_model = LinearRegression()

#train the model
mlr_model.fit(X_Train, Y_Train)
# Out:
# LinearRegression()

# %%
#predcting

y_pred = mlr_model.predict(X_Test)

# %%
y_pred
# Out:
# array([110275.88326465, 100454.99758739, 110275.88326465, 110275.88326465,
#        110275.88326465, 117264.95158837, 117264.95158837, 117264.95158837,
#        110275.88326465, 110275.88326465])

# %%
from sklearn.metrics import r2_score, mean_squared_error

print(mean_squared_error(Y_Test,y_pred))

print(r2_score(Y_Test,y_pred))
# Out:
# 1579823330.515047
# -0.23530668209751893
